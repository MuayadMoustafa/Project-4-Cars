# %%
import pandas as pd

# %%
df = pd.read_excel("C:/Users/Mua/Downloads/cars.xlsx")
df
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2            Buick Skylark 320    15.0         8        350.0      165.0
# 3           Plymouth Satellite    18.0         8        318.0      150.0
# 4                AMC Rebel SST    16.0         8        304.0      150.0
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL    27.0         4        140.0       86.0
# 403          Volkswagen Pickup    44.0         4         97.0       52.0
# 404              Dodge Rampage    32.0         4        135.0       84.0
# 405                Ford Ranger    28.0         4        120.0       79.0
# 406                 Chevy S-10    31.0         4        119.0       82.0
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %%
df.head(51)
# Out:
#                                  Car     MPG Cylinders Displacement  \
# 0                             STRING  DOUBLE       INT       DOUBLE
# 1          Chevrolet Chevelle Malibu    18.0         8        307.0
# 2                  Buick Skylark 320    15.0         8        350.0
# 3                 Plymouth Satellite    18.0         8        318.0
# 4                      AMC Rebel SST    16.0         8        304.0
# 5                        Ford Torino    17.0         8        302.0
# 6                   Ford Galaxie 500    15.0         8        429.0
# 7                   Chevrolet Impala    14.0         8        454.0
# 8                  Plymouth Fury iii    14.0         8        440.0
# 9                   Pontiac Catalina    14.0         8        455.0
# 10                AMC Ambassador DPL    15.0         8        390.0
# 11              Citroen DS-21 Pallas       0         4        133.0
# 12  Chevrolet Chevelle Concours (sw)       0         8        350.0
# ...

# %%
dff = df.head(51)
dff
# Out:
#                                  Car     MPG Cylinders Displacement  \
# 0                             STRING  DOUBLE       INT       DOUBLE
# 1          Chevrolet Chevelle Malibu    18.0         8        307.0
# 2                  Buick Skylark 320    15.0         8        350.0
# 3                 Plymouth Satellite    18.0         8        318.0
# 4                      AMC Rebel SST    16.0         8        304.0
# 5                        Ford Torino    17.0         8        302.0
# 6                   Ford Galaxie 500    15.0         8        429.0
# 7                   Chevrolet Impala    14.0         8        454.0
# 8                  Plymouth Fury iii    14.0         8        440.0
# 9                   Pontiac Catalina    14.0         8        455.0
# 10                AMC Ambassador DPL    15.0         8        390.0
# 11              Citroen DS-21 Pallas       0         4        133.0
# 12  Chevrolet Chevelle Concours (sw)       0         8        350.0
# ...

# %%
dff.describe()
# Out:
#                               Car   MPG  Cylinders  Displacement  Horsepower  \
# count                          51  51.0         51          51.0        51.0
# unique                         45  19.0          4          31.0        31.0
# top     Chevrolet Chevelle Malibu  14.0          8          97.0        95.0
# freq                            2   9.0         28           4.0         4.0
#
#         Weight  Acceleration  Model Origin
# count     51.0          51.0     51     51
# unique    49.0          23.0      3      4
# top     2130.0          15.5     70     US
# freq       2.0           7.0     35     39

# %%
dff.mode()
# Out:
#                          Car   MPG Cylinders Displacement Horsepower  Weight  \
# 0                AMC Gremlin  14.0         8         97.0       95.0  2130.0
# 1  Chevrolet Chevelle Malibu   NaN       NaN          NaN      150.0  3850.0
# 2           Chevrolet Impala   NaN       NaN          NaN        NaN     NaN
# 3               Datsun PL510   NaN       NaN          NaN        NaN     NaN
# 4           Ford Galaxie 500   NaN       NaN          NaN        NaN     NaN
# 5          Plymouth Fury iii   NaN       NaN          NaN        NaN     NaN
#
#   Acceleration Model Origin
# 0         15.5    70     US
# 1          NaN   NaN    NaN
# 2          NaN   NaN    NaN
# 3          NaN   NaN    NaN
# 4          NaN   NaN    NaN
# 5          NaN   NaN    NaN

# %%
df.describe()
# Out:
#                    Car    MPG  Cylinders  Displacement  Horsepower  Weight  \
# count              407  407.0        407         407.0       407.0   407.0
# unique             309  131.0          6          84.0        95.0   357.0
# top     Toyota Corolla   13.0          4          97.0       150.0  2130.0
# freq                 9   20.0        207          22.0        22.0     4.0
#
#         Acceleration  Model Origin
# count          407.0    407    407
# unique          97.0     14      4
# top             14.5     73     US
# freq            23.0     40    254

# %%
dff[["MPG","Acceleration"]]
# Out:
#        MPG Acceleration
# 0   DOUBLE       DOUBLE
# 1     18.0         12.0
# 2     15.0         11.5
# 3     18.0         11.0
# 4     16.0         12.0
# 5     17.0         10.5
# 6     15.0         10.0
# 7     14.0          9.0
# 8     14.0          8.5
# 9     14.0         10.0
# 10    15.0          8.5
# 11       0         17.5
# 12       0         11.5
# 13       0         11.0
# 14       0         10.5
# 15       0         11.0
# 16    15.0         10.0
# 17    14.0          8.0
# 18       0          8.0
# 19    15.0          9.5
# 20    14.0         10.0
# 21    24.0         15.0
# 22    22.0         15.5
# 23    18.0         15.5
# 24    21.0         16.0
# 25    27.0         14.5
# 26    26.0         20.5
# 27    25.0         17.5
# 28    24.0         14.5
# 29    25.0         17.5
# 30    26.0         12.5
# 31    21.0         15.0
# 32    10.0         14.0
# 33    10.0         15.0
# 34    11.0         13.5
# 35     9.0         18.5
# 36    27.0         14.5
# ...

# %%
df.count()
# Out:
# Car             407
# MPG             407
# Cylinders       407
# Displacement    407
# Horsepower      407
# Weight          407
# Acceleration    407
# Model           407
# Origin          407
# dtype: int64

# %%
dff.count()
# Out:
# Car             51
# MPG             51
# Cylinders       51
# Displacement    51
# Horsepower      51
# Weight          51
# Acceleration    51
# Model           51
# Origin          51
# dtype: int64

# %%
dff["Model"].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0     INT
# 1      70
# 2      70
# 3      70
# 4      70
# 5      70
# 6      70
# 7      70
# 8      70
# 9      70
# 10     70
# 11     70
# 12     70
# 13     70
# 14     70
# 15     70
# 16     70
# 17     70
# 18     70
# 19     70
# 20     70
# 21     70
# 22     70
# 23     70
# 24     70
# 25     70
# 26     70
# 27     70
# 28     70
# 29     70
# 30     70
# 31     70
# 32     70
# 33     70
# 34     70
# 35     70
# 36     71
# 37     71
# 38     71
# 39     71
# 40     71
# 41     71
# 42     71
# 43     71
# 44     71
# 45     71
# 46     71
# 47     71
# 48     71
# 49     71
# 50     71
# Name: Model, dtype: object>

# %%
dff
# Out:
#                                  Car     MPG Cylinders Displacement  \
# 0                             STRING  DOUBLE       INT       DOUBLE
# 1          Chevrolet Chevelle Malibu    18.0         8        307.0
# 2                  Buick Skylark 320    15.0         8        350.0
# 3                 Plymouth Satellite    18.0         8        318.0
# 4                      AMC Rebel SST    16.0         8        304.0
# 5                        Ford Torino    17.0         8        302.0
# 6                   Ford Galaxie 500    15.0         8        429.0
# 7                   Chevrolet Impala    14.0         8        454.0
# 8                  Plymouth Fury iii    14.0         8        440.0
# 9                   Pontiac Catalina    14.0         8        455.0
# 10                AMC Ambassador DPL    15.0         8        390.0
# 11              Citroen DS-21 Pallas       0         4        133.0
# 12  Chevrolet Chevelle Concours (sw)       0         8        350.0
# ...

# %%
dff["Car"]
# Out:
# 0                               STRING
# 1            Chevrolet Chevelle Malibu
# 2                    Buick Skylark 320
# 3                   Plymouth Satellite
# 4                        AMC Rebel SST
# 5                          Ford Torino
# 6                     Ford Galaxie 500
# 7                     Chevrolet Impala
# 8                    Plymouth Fury iii
# 9                     Pontiac Catalina
# 10                  AMC Ambassador DPL
# 11                Citroen DS-21 Pallas
# 12    Chevrolet Chevelle Concours (sw)
# 13                    Ford Torino (sw)
# 14             Plymouth Satellite (sw)
# 15                  AMC Rebel SST (sw)
# 16                 Dodge Challenger SE
# 17                  Plymouth 'Cuda 340
# 18               Ford Mustang Boss 302
# 19               Chevrolet Monte Carlo
# 20             Buick Estate Wagon (sw)
# 21              Toyota Corolla Mark ii
# 22                     Plymouth Duster
# 23                          AMC Hornet
# ...
